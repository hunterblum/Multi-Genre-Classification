# %% [markdown]
# # Notebook 5 - Model Explanation
# This notebook will highlight the key words for each predicted genre to aid model explainability.

# %%
import numpy as np
import pandas as pd
from ast import literal_eval
import pickle
import eli5
from IPython.display import display, HTML

import warnings
warnings.filterwarnings("ignore")

# %%
# Import trained model and fitted TF-IDF Vectorizer
model = pickle.load(open('templates/model.pkl', 'rb'))
vectorizer = pickle.load(open('templates/vectorizer.pkl','rb'))

# %%
# Display overall word contribution to each genre
class_names = [["Not Country", "Country"], 
               ["Not Pop", "Pop"], 
               ["Not R&B", "R&B"], 
               ["Not Rap", "Rap"], 
               ["Not Rock", "Rock"]]

for i in range(0,5):
    display(HTML(
        eli5.show_weights(
            model.estimators_[i],
            top = 10,
            vec = vectorizer,
            target_names = class_names[i]
        ).data)
    )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=Country
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +12.854
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         thorns
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.585
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mmh
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.980
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hanging
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.662
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         everyones
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.319
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         planned
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.181
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         whiskey
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.125
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dreaming
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 92.57%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 8796 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.57%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 18857 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.123
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         also
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -5.085
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hangin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.769
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mm
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=Pop
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.181
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mm
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.665
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hangin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.747
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         manipulate
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.426
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sang
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.146
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         stress
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 86.38%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 10663 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.20%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 22732 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.796
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfеct
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.798
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         likecause
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hang
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.909
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         werе
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -5.253
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mmh
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=R&B
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.164
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mm
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.119
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         club
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.027
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         issues
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 84.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 8712 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.19%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 23333 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.977
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bossed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.026
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         drowning
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.116
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         stuntin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.139
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.430
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         someday
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.535
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cmon
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 81.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.595
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         everyones
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=Rap
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.980
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         closed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.908
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         rap
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.579
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bossed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.473
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         uh
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.391
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bruno
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.330
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         closer
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.301
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         stressed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.287
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bronx
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.258
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         loner
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.239
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flexin
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 83.62%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 15802 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 14931 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=Rock
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.816
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         blocked
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.415
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         beating
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.113
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         colder
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 92.56%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 8093 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.57%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 22601 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.109
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         block
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.257
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         laa
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 91.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.539
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         misunderstood
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 91.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.597
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         uh
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.975
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         thе
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -5.897
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wе
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -12.799
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         thorns
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
preproc_df = pd.read_csv("data/genre_prepped.csv.gz", compression = "gzip",
                         converters = {"tokens": literal_eval, "genre" : literal_eval})

# %%
# Display word contributions for a single prediction/song
for i in range(0,5):
    display(HTML(
        eli5.show_prediction(
            model.estimators_[i],
            # Test with first song - genre = country
            # 5 outputs should be: country, not pop, not R&B, not rap, and not rock
            preproc_df["lyrics_clean"].iloc[0],
            vec = vectorizer,
            target_names = class_names[i]
        ).data)
    )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=Country
#
# </b>
#
#
#     (probability <b>0.688</b>, score <b>1.000</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.571
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.571
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 72.97%); opacity: 0.91" title="0.130">betty</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.21%); opacity: 0.81" title="-0.011">make</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.16%); opacity: 0.82" title="0.022">assumptions</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.54%); opacity: 0.81" title="0.007">switched</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.52%); opacity: 0.83" title="0.029">homeroom</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.54%); opacity: 0.81" title="0.010">think</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.59%); opacity: 0.82" title="-0.025">cause</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 72.97%); opacity: 0.91" title="0.130">betty</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.61%); opacity: 0.80" title="0.004">one</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.89%); opacity: 0.80" title="-0.001">time</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.62%); opacity: 0.86" title="0.063">riding</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.38%); opacity: 0.82" title="0.021">skateboard</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.31%); opacity: 0.82" title="0.022">passed</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.02%); opacity: 0.81" title="0.008">house</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.83%); opacity: 0.86" title="0.068">breathe</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.45%); opacity: 0.84" title="-0.048">heard</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.52%); opacity: 0.83" title="0.034">rumors</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84